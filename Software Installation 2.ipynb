# %%
# !source activate
# !conda deactivate
# !conda activate naturalistic
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda deactivate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !pip install git+https://github.com/FIU-Neuro/brainconn#egg=brainconn
# Out:
# Collecting brainconn
#   Cloning https://github.com/FIU-Neuro/brainconn to /private/var/folders/h9/b4fl72pj2254z2q1503mxdd00000gn/T/pip-install-b0aoi561/brainconn_06592fadc5f044c788d5e98949aaf279
#   Running command git clone --quiet https://github.com/FIU-Neuro/brainconn /private/var/folders/h9/b4fl72pj2254z2q1503mxdd00000gn/T/pip-install-b0aoi561/brainconn_06592fadc5f044c788d5e98949aaf279
#   Resolved https://github.com/FIU-Neuro/brainconn to commit 8cd436a885c9f823ef7789aa032cc2119318ff59
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/chunyilee/miniconda3/lib/python3.10/site-packages (from brainconn) (1.23.5)
# Requirement already satisfied: scipy in /Users/chunyilee/miniconda3/lib/python3.10/site-packages (from brainconn) (1.10.0)
# Building wheels for collected packages: brainconn
#   Building wheel for brainconn (setup.py) ... done
#   Created wheel for brainconn: filename=brainconn-0.0.1-py3-none-any.whl size=108871 sha256=d59b0a8585b44bd46515c8d65c3b8effd06fdf9d2fafb06a7dedd670889b9167
#   Stored in directory: /private/var/folders/h9/b4fl72pj2254z2q1503mxdd00000gn/T/pip-ephem-wheel-cache-uibn6vge/wheels/3b/cb/60/093f3f43132a041b25dc0e2cc8641882231156608cc7d67ca5
# Successfully built brainconn
# Installing collected packages: brainconn
# Successfully installed brainconn-0.0.1

# %%
# !conda install -c brainiak -c defaults -c conda-forge brainiak
# Out:
# Collecting package metadata (current_repodata.json): failed
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/gateways/repodata/__init__.py", line 161, in conda_http_errors
#         yield
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/gateways/repodata/__init__.py", line 127, in repodata
#         response.raise_for_status()
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/requests/models.py", line 1021, in raise_for_status
#         raise HTTPError(http_error_msg, response=self)
#     requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://conda.anaconda.org/brainiak/noarch/current_repodata.json
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 366, in _load
#         raw_repodata_str = self._repo.repodata(cache.state)  # type: ignore
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/gateways/repodata/__init__.py", line 120, in repodata
#         with conda_http_errors(self._url, filename):
#       File "/Users/chunyilee/miniconda3/lib/python3.10/contextlib.py", line 153, in __exit__
#         self.gen.throw(typ, value, traceback)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/gateways/repodata/__init__.py", line 226, in conda_http_errors
#         raise UnavailableInvalidChannel(
#     conda.exceptions.UnavailableInvalidChannel: HTTP 404 NOT FOUND for channel brainiak <https://conda.anaconda.org/brainiak>
#
#     The channel is not accessible or is invalid.
#
#     You will need to adjust your conda configuration to proceed.
#     Use `conda config --show channels` to view your configuration's current state,
#     and use `conda config --show-sources` to view config file locations.
#
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/exceptions.py", line 1132, in __call__
#         return func(*args, **kwargs)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/cli/main.py", line 69, in main_subshell
#         exit_code = do_call(args, p)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/cli/conda_argparse.py", line 122, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/notices/core.py", line 121, in wrapper
#         return func(*args, **kwargs)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/cli/main_install.py", line 20, in execute
#         install(args, parser, 'install')
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/cli/install.py", line 264, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/solve.py", line 134, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/solve.py", line 177, in solve_for_diff
#         final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/solve.py", line 282, in solve_final_state
#         ssc = self._collect_all_metadata(ssc)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/common/io.py", line 84, in decorated
#         return f(*args, **kwds)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/solve.py", line 449, in _collect_all_metadata
#         index, r = self._prepare(prepared_specs)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/solve.py", line 1064, in _prepare
#         reduced_index = get_reduced_index(self.prefix, self.channels,
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/index.py", line 267, in get_reduced_index
#         new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 169, in query_all
#         result = tuple(chain.from_iterable(executor.map(subdir_query, channel_urls)))
#       File "/Users/chunyilee/miniconda3/lib/python3.10/concurrent/futures/_base.py", line 621, in result_iterator
#         yield _result_or_cancel(fs.pop())
#       File "/Users/chunyilee/miniconda3/lib/python3.10/concurrent/futures/_base.py", line 319, in _result_or_cancel
#         return fut.result(timeout)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/concurrent/futures/_base.py", line 451, in result
#         return self.__get_result()
#       File "/Users/chunyilee/miniconda3/lib/python3.10/concurrent/futures/_base.py", line 403, in __get_result
#         raise self._exception
#       File "/Users/chunyilee/miniconda3/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#         result = self.fn(*self.args, **self.kwargs)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 158, in subdir_query
#         return tuple(
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 174, in query
#         self.load()
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 264, in load
#         _internal_state = self._load()
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 379, in _load
#         return self._load()
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/core/subdir_data.py", line 315, in _load
#         cache.load_state()  # XXX should this succeed even if FileNotFound?
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/gateways/repodata/__init__.py", line 570, in load_state
#         self.load(state_only=True)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/site-packages/conda/gateways/repodata/__init__.py", line 528, in load
#         state = json.loads(state_file.read())
#       File "/Users/chunyilee/miniconda3/lib/python3.10/json/__init__.py", line 346, in loads
#         return _default_decoder.decode(s)
#       File "/Users/chunyilee/miniconda3/lib/python3.10/json/decoder.py", line 340, in decode
#         raise JSONDecodeError("Extra data", s, end)
#     json.decoder.JSONDecodeError: Extra data: line 7 column 2 (char 186)
#
# `$ /Users/chunyilee/miniconda3/bin/conda install -c brainiak -c defaults -c conda-forge brainiak`
#
#   environment variables:
#                  CIO_TEST=<not set>
#         CONDA_DEFAULT_ENV=base
#                 CONDA_EXE=/Users/chunyilee/miniconda3/bin/conda
#              CONDA_PREFIX=/Users/chunyilee/miniconda3
#     CONDA_PROMPT_MODIFIER=(base)
#          CONDA_PYTHON_EXE=/Users/chunyilee/miniconda3/bin/python
#                CONDA_ROOT=/Users/chunyilee/miniconda3
#               CONDA_SHLVL=1
#            CURL_CA_BUNDLE=<not set>
#                LD_PRELOAD=<not set>
#                      PATH=/opt/local/bin:/opt/local/sbin:/Users/chunyilee/miniconda3/bin:/Users/
#                           chunyilee/miniconda3/condabin:/Users/chunyilee/.nvm/versions/node/v10.
#                           16.3/bin:/Library/Frameworks/Python.framework/Versions/3.7/bin:/Users/
#                           chunyilee/anaconda3/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/
#                           opt/X11/bin
#        REQUESTS_CA_BUNDLE=<not set>
#             SSL_CERT_FILE=<not set>
#
#      active environment : base
#     active env location : /Users/chunyilee/miniconda3
#             shell level : 1
#        user config file : /Users/chunyilee/.condarc
#  populated config files : /Users/chunyilee/.condarc
#           conda version : 23.3.1
#     conda-build version : not installed
#          python version : 3.10.9.final.0
#        virtual packages : __archspec=1=x86_64
#                           __osx=10.16=0
#                           __unix=0=0
#        base environment : /Users/chunyilee/miniconda3  (writable)
#       conda av data dir : /Users/chunyilee/miniconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://conda.anaconda.org/brainiak/osx-64
#                           https://conda.anaconda.org/brainiak/noarch
#                           https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://conda.anaconda.org/conda-forge/osx-64
#                           https://conda.anaconda.org/conda-forge/noarch
#           package cache : /Users/chunyilee/miniconda3/pkgs
#                           /Users/chunyilee/.conda/pkgs
#        envs directories : /Users/chunyilee/miniconda3/envs
#                           /Users/chunyilee/.conda/envs
#                platform : osx-64
#              user-agent : conda/23.3.1 requests/2.28.1 CPython/3.10.9 Darwin/21.6.0 OSX/10.16
#                 UID:GID : 501:20
#              netrc file : None
#            offline mode : False
#
#
# An unexpected error has occurred. Conda has prepared the above report.
#
# If submitted, this report will be used by core maintainers to improve
# future releases of conda.
# Would you like conda to send this report to the core maintainers? [y/N]:
# Timeout reached. No report sent.

# %%
# !pip install nibabel datalad nilearn nltools hypertools timecorr pliers statesegmentation networkx nltk requests urllib3
